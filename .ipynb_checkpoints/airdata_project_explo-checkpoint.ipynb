# %% [markdown]
# # EXPLORATION AIRDATA

# %% [markdown]
# ## Importation des données

# %%
import pandas as pd
df = pd.read_csv("airdata_dataset/2016_01.csv",sep=",")

#POUR IMPORTER TOUTES LES DONNÉES, IL FAUT UTILISER LE CODE SUIVANT

#for i in range(2,10):
#    print(i)
#    df = df.append(pd.read_csv("airdata_dataset/2016_0"+str(i)+".csv",sep=",",error_bad_lines=False))

#for i in range(10,13):
#    print(i)
#    df = df.append(pd.read_csv("airdata_dataset/2016_"+str(i)+".csv",sep=",",error_bad_lines=False))

# %%
df.describe(include="all")
# Out:
#             YEAR   QUARTER     MONTH   DAY_OF_MONTH    DAY_OF_WEEK  \
# count   445827.0  445827.0  445827.0  445827.000000  445827.000000
# unique       NaN       NaN       NaN            NaN            NaN
# top          NaN       NaN       NaN            NaN            NaN
# freq         NaN       NaN       NaN            NaN            NaN
# mean      2016.0       1.0       1.0      15.893510       4.113815
# std          0.0       0.0       0.0       8.936692       2.005007
# min       2016.0       1.0       1.0       1.000000       1.000000
# 25%       2016.0       1.0       1.0       8.000000       2.000000
# 50%       2016.0       1.0       1.0      16.000000       4.000000
# 75%       2016.0       1.0       1.0      24.000000       6.000000
# max       2016.0       1.0       1.0      31.000000       7.000000
#
#            FL_DATE UNIQUE_CARRIER     AIRLINE_ID CARRIER TAIL_NUM  ...  \
# count       445827         445827  445827.000000  445827   441583  ...
# unique          31             12            NaN      12     4238  ...
# top     2016-01-03             WN            NaN      WN   N489HA  ...
# freq         15878         104154            NaN  104154      358  ...
# mean           NaN            NaN   19903.085069     NaN      NaN  ...
# std            NaN            NaN     382.853084     NaN      NaN  ...
# min            NaN            NaN   19393.000000     NaN      NaN  ...
# 25%            NaN            NaN   19790.000000     NaN      NaN  ...
# 50%            NaN            NaN   19805.000000     NaN      NaN  ...
# 75%            NaN            NaN   20304.000000     NaN      NaN  ...
# max            NaN            NaN   21171.000000     NaN      NaN  ...
#
#         DISTANCE_GROUP  CARRIER_DELAY  WEATHER_DELAY     NAS_DELAY  \
# count    445827.000000   70882.000000   70882.000000  70882.000000
# unique             NaN            NaN            NaN           NaN
# top                NaN            NaN            NaN           NaN
# freq               NaN            NaN            NaN           NaN
# mean          3.848746      20.921912       2.836573     12.680455
# std           2.396397      57.041917      23.306995     24.859425
# min           1.000000       0.000000       0.000000      0.000000
# 25%           2.000000       0.000000       0.000000      0.000000
# 50%           3.000000       2.000000       0.000000      2.000000
# 75%           5.000000      20.000000       0.000000     18.000000
# max          11.000000    1659.000000    1093.000000    755.000000
#
#        SECURITY_DELAY LATE_AIRCRAFT_DELAY FIRST_DEP_TIME  TOTAL_ADD_GTIME  \
# count    70882.000000        70882.000000    2552.000000      2552.000000
# unique            NaN                 NaN            NaN              NaN
# top               NaN                 NaN            NaN              NaN
# freq              NaN                 NaN            NaN              NaN
# mean         0.080415           21.635450    1236.022335        32.054075
# std          2.070844           41.991917     513.040425        25.993098
# min          0.000000            0.000000       6.000000         1.000000
# 25%          0.000000            0.000000     805.000000        15.000000
# 50%          0.000000            0.000000    1149.000000        25.000000
# 75%          0.000000           26.000000    1657.000000        39.000000
# max        242.000000         1158.000000    2354.000000       176.000000
#
#        LONGEST_ADD_GTIME  Unnamed: 64
# count        2552.000000          0.0
# unique               NaN          NaN
# top                  NaN          NaN
# freq                 NaN          NaN
# mean           31.776254          NaN
# std            25.698255          NaN
# min             1.000000          NaN
# 25%            15.000000          NaN
# 50%            25.000000          NaN
# 75%            39.000000          NaN
# max           176.000000          NaN
#
# [11 rows x 65 columns]

# %% [markdown]
# On supprime la dernière colonne due à une virgule de trop dans le fichier csv.

# %%
df.drop(df.columns[len(df.columns)-1], axis=1, inplace=True)

# %% [markdown]
# ## Traitement des NAs

# %%
print("Pourcentage de NAs par colonnes")
(df.isna().sum(axis=0)[((df.isna().sum(axis=0)/len(df))*100)>0]/len(df))*100
# Out:
# Pourcentage de NAs par colonnes
# TAIL_NUM                0.951939
# DEP_TIME                2.573420
# DEP_DELAY               2.573420
# DEP_DELAY_NEW           2.573420
# DEP_DEL15               2.573420
# DEP_DELAY_GROUP         2.573420
# TAXI_OUT                2.601906
# WHEELS_OFF              2.601906
# WHEELS_ON               2.670767
# TAXI_IN                 2.670767
# ARR_TIME                2.670767
# ARR_DELAY               2.810283
# ARR_DELAY_NEW           2.810283
# ARR_DEL15               2.810283
# ARR_DELAY_GROUP         2.810283
# CANCELLATION_CODE      97.383514
# ACTUAL_ELAPSED_TIME     2.810283
# AIR_TIME                2.810283
# CARRIER_DELAY          84.101008
# WEATHER_DELAY          84.101008
# NAS_DELAY              84.101008
# SECURITY_DELAY         84.101008
# LATE_AIRCRAFT_DELAY    84.101008
# FIRST_DEP_TIME         99.427581
# TOTAL_ADD_GTIME        99.427581
# LONGEST_ADD_GTIME      99.427581
# dtype: float64

# %%
df[df["TAIL_NUM"].isna()]
# Out:
#         QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK UNIQUE_CARRIER TAIL_NUM  \
# 79            1      1            23            6             AA      NaN
# 110           1      1            23            6             AA      NaN
# 111           1      1            24            7             AA      NaN
# 260           1      1            22            5             AA      NaN
# 261           1      1            23            6             AA      NaN
# 262           1      1            24            7             AA      NaN
# 263           1      1            25            1             AA      NaN
# 490           1      1             5            2             AA      NaN
# 574           1      1            23            6             AA      NaN
# 575           1      1            24            7             AA      NaN
# 605           1      1            23            6             AA      NaN
# 635           1      1            23            6             AA      NaN
# 636           1      1            24            7             AA      NaN
# 665           1      1            23            6             AA      NaN
# 666           1      1            24            7             AA      NaN
# 878           1      1            23            6             AA      NaN
# 879           1      1            24            7             AA      NaN
# 909           1      1            23            6             AA      NaN
# 910           1      1            24            7             AA      NaN
# 1009          1      1            23            6             AA      NaN
# 1100          1      1            23            6             AA      NaN
# 1101          1      1            24            7             AA      NaN
# 1364          1      1            23            6             AA      NaN
# 1395          1      1            23            6             AA      NaN
# 1660          1      1            24            7             AA      NaN
# 1687          1      1            23            6             AA      NaN
# 1716          1      1            23            6             AA      NaN
# 1717          1      1            24            7             AA      NaN
# 1718          1      1            25            1             AA      NaN
# 1918          1      1            24            7             AA      NaN
# ...         ...    ...           ...          ...            ...      ...
# 420727        1      1            24            7             WN      NaN
# 420728        1      1            24            7             WN      NaN
# 420729        1      1            24            7             WN      NaN
# 420733        1      1            24            7             WN      NaN
# 420734        1      1            24            7             WN      NaN
# 421037        1      1            24            7             WN      NaN
# 421039        1      1            24            7             WN      NaN
# 421043        1      1            24            7             WN      NaN
# 421044        1      1            24            7             WN      NaN
# 421046        1      1            24            7             WN      NaN
# 421049        1      1            24            7             WN      NaN
# 421056        1      1            24            7             WN      NaN
# 421104        1      1            24            7             WN      NaN
# 421339        1      1            25            1             WN      NaN
# 421341        1      1            25            1             WN      NaN
# 421359        1      1            25            1             WN      NaN
# 421367        1      1            25            1             WN      NaN
# 421369        1      1            25            1             WN      NaN
# 424474        1      1            25            1             WN      NaN
# 424481        1      1            25            1             WN      NaN
# 424484        1      1            25            1             WN      NaN
# 424491        1      1            25            1             WN      NaN
# 425078        1      1            27            3             WN      NaN
# 437304        1      1            26            2             WN      NaN
# 441859        1      1            12            2             WN      NaN
# 442391        1      1            26            2             WN      NaN
# 442396        1      1            26            2             WN      NaN
# 442659        1      1            26            2             WN      NaN
# 442819        1      1            26            2             WN      NaN
# 443088        1      1            26            2             WN      NaN
#
#         FL_NUM  ORIGIN_AIRPORT_ID  ORIGIN_CITY_MARKET_ID  ORIGIN_STATE_FIPS  \
# 79          44              14747                  30559                 53
# 110         45              12478                  31703                 36
# 111         45              12478                  31703                 36
# 260         52              12892                  32575                  6
# 261         52              12892                  32575                  6
# 262         52              12892                  32575                  6
# 263         52              12892                  32575                  6
# 490         61              13303                  32467                 12
# 574         64              13303                  32467                 12
# 575         64              13303                  32467                 12
# 605         65              12478                  31703                 36
# 635         66              10423                  30423                 48
# 636         66              10423                  30423                 48
# 665         67              12478                  31703                 36
# 666         67              12478                  31703                 36
# 878         75              12478                  31703                 36
# 879         75              12478                  31703                 36
# 909         76              13204                  31454                 12
# 910         76              13204                  31454                 12
# 1009       196              15024                  34945                 78
# 1100       200              12478                  31703                 36
# 1101       200              12478                  31703                 36
# 1364       210              12889                  32211                 32
# 1395       211              12478                  31703                 36
# 1660         1              12478                  31703                 36
# 1687         2              12892                  32575                  6
# 1716         3              12478                  31703                 36
# 1717         3              12478                  31703                 36
# 1718         3              12478                  31703                 36
# 1918         9              12478                  31703                 36
# ...        ...                ...                    ...                ...
# 420727    1503              12391                  31703                 36
# 420728     667              12391                  31703                 36
# 420729    1519              12391                  31703                 36
# 420733    1199              12391                  31703                 36
# 420734    1746              12391                  31703                 36
# 421037     150              12953                  31703                 36
# 421039    1345              12953                  31703                 36
# 421043    2670              12953                  31703                 36
# 421044     255              12953                  31703                 36
# 421046    1011              12953                  31703                 36
# 421049     829              12953                  31703                 36
# 421056    1533              12953                  31703                 36
# 421104     451              13198                  33198                 29
# 421339     856              14321                  34321                 23
# 421341     406              14492                  34492                 37
# 421359    2095              14492                  34492                 37
# 421367    2872              14524                  34524                 51
# 421369     102              14524                  34524                 51
# 424474    1377              14100                  34100                 42
# 424481    2945              14100                  34100                 42
# 424484    1084              14100                  34100                 42
# 424491    2375              14100                  34100                 42
# 425078    1490              11618                  31703                 34
# 437304     609              11292                  30325                  8
# 441859     941              11066                  31066                 39
# 442391    1490              11618                  31703                 34
# 442396    1495              11618                  31703                 34
# 442659    1710              12339                  32337                 18
# 442819     779              12889                  32211                 32
# 443088    1131              13198                  33198                 29
#
#         ...  AIR_TIME  DISTANCE  CARRIER_DELAY  WEATHER_DELAY  NAS_DELAY  \
# 79      ...       NaN    2422.0            NaN            NaN        NaN
# 110     ...       NaN    2422.0            NaN            NaN        NaN
# 111     ...       NaN    2422.0            NaN            NaN        NaN
# 260     ...       NaN    2311.0            NaN            NaN        NaN
# 261     ...       NaN    2311.0            NaN            NaN        NaN
# 262     ...       NaN    2311.0            NaN            NaN        NaN
# 263     ...       NaN    2311.0            NaN            NaN        NaN
# 490     ...       NaN    1121.0            NaN            NaN        NaN
# 574     ...       NaN    1089.0            NaN            NaN        NaN
# 575     ...       NaN    1089.0            NaN            NaN        NaN
# 605     ...       NaN    1089.0            NaN            NaN        NaN
# 635     ...       NaN    1521.0            NaN            NaN        NaN
# 636     ...       NaN    1521.0            NaN            NaN        NaN
# 665     ...       NaN    1521.0            NaN            NaN        NaN
# 666     ...       NaN    1521.0            NaN            NaN        NaN
# 878     ...       NaN     944.0            NaN            NaN        NaN
# 879     ...       NaN     944.0            NaN            NaN        NaN
# 909     ...       NaN     944.0            NaN            NaN        NaN
# 910     ...       NaN     944.0            NaN            NaN        NaN
# 1009    ...       NaN    1623.0            NaN            NaN        NaN
# 1100    ...       NaN    1089.0            NaN            NaN        NaN
# 1101    ...       NaN    1089.0            NaN            NaN        NaN
# 1364    ...       NaN    2248.0            NaN            NaN        NaN
# 1395    ...       NaN    2248.0            NaN            NaN        NaN
# 1660    ...       NaN    2475.0            NaN            NaN        NaN
# 1687    ...       NaN    2475.0            NaN            NaN        NaN
# 1716    ...       NaN    2475.0            NaN            NaN        NaN
# 1717    ...       NaN    2475.0            NaN            NaN        NaN
# 1718    ...       NaN    2475.0            NaN            NaN        NaN
# 1918    ...       NaN    2586.0            NaN            NaN        NaN
# ...     ...       ...       ...            ...            ...        ...
# 420727  ...       NaN     220.0            NaN            NaN        NaN
# 420728  ...       NaN    1092.0            NaN            NaN        NaN
# 420729  ...       NaN    1092.0            NaN            NaN        NaN
# 420733  ...       NaN    1052.0            NaN            NaN        NaN
# 420734  ...       NaN    1034.0            NaN            NaN        NaN
# 421037  ...       NaN     764.0            NaN            NaN        NaN
# 421039  ...       NaN    1381.0            NaN            NaN        NaN
# 421043  ...       NaN    1620.0            NaN            NaN        NaN
# 421044  ...       NaN    1428.0            NaN            NaN        NaN
# 421046  ...       NaN     660.0            NaN            NaN        NaN
# 421049  ...       NaN     725.0            NaN            NaN        NaN
# 421056  ...       NaN     888.0            NaN            NaN        NaN
# 421104  ...       NaN    1107.0            NaN            NaN        NaN
# 421339  ...       NaN     452.0            NaN            NaN        NaN
# 421341  ...       NaN     356.0            NaN            NaN        NaN
# 421359  ...       NaN     534.0            NaN            NaN        NaN
# 421367  ...       NaN     481.0            NaN            NaN        NaN
# 421369  ...       NaN     667.0            NaN            NaN        NaN
# 424474  ...       NaN    1558.0            NaN            NaN        NaN
# 424481  ...       NaN     861.0            NaN            NaN        NaN
# 424484  ...       NaN     668.0            NaN            NaN        NaN
# 424491  ...       NaN     814.0            NaN            NaN        NaN
# 425078  ...       NaN     711.0            NaN            NaN        NaN
#         LONGEST_ADD_GTIME
# 79                    NaN
# 110                   NaN
# 111                   NaN
# 260                   NaN
# 261                   NaN
# 262                   NaN
# 263                   NaN
# 490                   NaN
# 574                   NaN
# 575                   NaN
# 605                   NaN
# 635                   NaN
# 636                   NaN
# 665                   NaN
# 666                   NaN
# 878                   NaN
# 879                   NaN
# 909                   NaN
# 910                   NaN
# 1009                  NaN
# 1100                  NaN
# 1101                  NaN
# 1364                  NaN
# 1395                  NaN
# 1660                  NaN
# 1687                  NaN
# 1716                  NaN
# 1717                  NaN
# 1718                  NaN
# 1918                  NaN
# ...                   ...
# 420727                NaN
# 420728                NaN
# 420729                NaN
# 420733                NaN
# 420734                NaN
# 421037                NaN
# 421039                NaN
# 421043                NaN
# 421044                NaN
# 421046                NaN
# 421049                NaN
# 421056                NaN
# 421104                NaN
# 421339                NaN
# 421341                NaN
# 421359                NaN
# 421367                NaN
# 421369                NaN
# 424474                NaN
# 424481                NaN
# 424484                NaN
# 424491                NaN
# 425078                NaN
# 437304                NaN
# 441859                NaN
# 442391                NaN
# 442396                NaN
# 442659                NaN
# 442819                NaN
# 443088                NaN
#
# [4244 rows x 40 columns]

# %%
print(df.columns)
# Out:
# Index(['YEAR', 'QUARTER', 'MONTH', 'DAY_OF_MONTH', 'DAY_OF_WEEK', 'FL_DATE',
#        'UNIQUE_CARRIER', 'AIRLINE_ID', 'CARRIER', 'TAIL_NUM', 'FL_NUM',
#        'ORIGIN_AIRPORT_ID', 'ORIGIN_AIRPORT_SEQ_ID', 'ORIGIN_CITY_MARKET_ID',
#        'ORIGIN', 'ORIGIN_CITY_NAME', 'ORIGIN_STATE_ABR', 'ORIGIN_STATE_FIPS',
#        'ORIGIN_STATE_NM', 'ORIGIN_WAC', 'DEST_AIRPORT_ID',
#        'DEST_AIRPORT_SEQ_ID', 'DEST_CITY_MARKET_ID', 'DEST', 'DEST_CITY_NAME',
#        'DEST_STATE_ABR', 'DEST_STATE_FIPS', 'DEST_STATE_NM', 'DEST_WAC',
#        'CRS_DEP_TIME', 'DEP_TIME', 'DEP_DELAY', 'DEP_DELAY_NEW', 'DEP_DEL15',
#        'DEP_DELAY_GROUP', 'DEP_TIME_BLK', 'TAXI_OUT', 'WHEELS_OFF',
#        'WHEELS_ON', 'TAXI_IN', 'CRS_ARR_TIME', 'ARR_TIME', 'ARR_DELAY',
#        'ARR_DELAY_NEW', 'ARR_DEL15', 'ARR_DELAY_GROUP', 'ARR_TIME_BLK',
#        'CANCELLED', 'CANCELLATION_CODE', 'DIVERTED', 'CRS_ELAPSED_TIME',
#        'ACTUAL_ELAPSED_TIME', 'AIR_TIME', 'FLIGHTS', 'DISTANCE',
#        'DISTANCE_GROUP', 'CARRIER_DELAY', 'WEATHER_DELAY', 'NAS_DELAY',
#        'SECURITY_DELAY', 'LATE_AIRCRAFT_DELAY', 'FIRST_DEP_TIME',
#        'TOTAL_ADD_GTIME', 'LONGEST_ADD_GTIME'],
#       dtype='object')

# %%
df.shape
# Out:
# (445827, 64)

# %%
columns_to_drop = ["YEAR","FL_DATE","AIRLINE_ID","CARRIER","ORIGIN_AIRPORT_SEQ_ID","ORIGIN","ORIGIN_CITY_NAME","ORIGIN_STATE_ABR","ORIGIN_STATE_NM","DEST_AIRPORT_SEQ_ID","DEST","DEST_CITY_NAME","DEST_STATE_ABR","DEST_STATE_NM"]
df.drop(columns_to_drop, axis=1, inplace=True)
df.shape
# Out:
# (445827, 50)

# %%
print(df.columns)
# Out:
# Index(['QUARTER', 'MONTH', 'DAY_OF_MONTH', 'DAY_OF_WEEK', 'UNIQUE_CARRIER',
#        'TAIL_NUM', 'FL_NUM', 'ORIGIN_AIRPORT_ID', 'ORIGIN_CITY_MARKET_ID',
#        'ORIGIN_STATE_FIPS', 'ORIGIN_WAC', 'DEST_AIRPORT_ID',
#        'DEST_CITY_MARKET_ID', 'DEST_STATE_FIPS', 'DEST_WAC', 'CRS_DEP_TIME',
#        'DEP_TIME', 'DEP_DELAY', 'DEP_DELAY_NEW', 'DEP_DEL15',
#        'DEP_DELAY_GROUP', 'DEP_TIME_BLK', 'TAXI_OUT', 'WHEELS_OFF',
#        'WHEELS_ON', 'TAXI_IN', 'CRS_ARR_TIME', 'ARR_TIME', 'ARR_DELAY',
#        'ARR_DELAY_NEW', 'ARR_DEL15', 'ARR_DELAY_GROUP', 'ARR_TIME_BLK',
#        'CANCELLED', 'CANCELLATION_CODE', 'DIVERTED', 'CRS_ELAPSED_TIME',
#        'ACTUAL_ELAPSED_TIME', 'AIR_TIME', 'FLIGHTS', 'DISTANCE',
#        'DISTANCE_GROUP', 'CARRIER_DELAY', 'WEATHER_DELAY', 'NAS_DELAY',
#        'SECURITY_DELAY', 'LATE_AIRCRAFT_DELAY', 'FIRST_DEP_TIME',
#        'TOTAL_ADD_GTIME', 'LONGEST_ADD_GTIME'],
#       dtype='object')

# %%
df.describe(include="all")
# Out:
#          QUARTER     MONTH   DAY_OF_MONTH    DAY_OF_WEEK UNIQUE_CARRIER  \
# count   445827.0  445827.0  445827.000000  445827.000000         445827
# unique       NaN       NaN            NaN            NaN             12
# top          NaN       NaN            NaN            NaN             WN
# freq         NaN       NaN            NaN            NaN         104154
# mean         1.0       1.0      15.893510       4.113815            NaN
# std          0.0       0.0       8.936692       2.005007            NaN
# min          1.0       1.0       1.000000       1.000000            NaN
# 25%          1.0       1.0       8.000000       2.000000            NaN
# 50%          1.0       1.0      16.000000       4.000000            NaN
# 75%          1.0       1.0      24.000000       6.000000            NaN
# max          1.0       1.0      31.000000       7.000000            NaN
#
#        TAIL_NUM         FL_NUM  ORIGIN_AIRPORT_ID  ORIGIN_CITY_MARKET_ID  \
# count    441583  445827.000000      445827.000000          445827.000000
# unique     4238            NaN                NaN                    NaN
# top      N489HA            NaN                NaN                    NaN
# freq        358            NaN                NaN                    NaN
# mean        NaN    2078.856456       12682.120789           31723.938281
# std         NaN    1757.269780        1529.485604            1280.460591
# min         NaN       1.000000       10135.000000           30070.000000
# 25%         NaN     702.000000       11292.000000           30615.000000
# 50%         NaN    1594.000000       12889.000000           31453.000000
# 75%         NaN    2763.000000       14027.000000           32467.000000
# max         NaN    7438.000000       16218.000000           35991.000000
#
#         ORIGIN_STATE_FIPS  ...       DISTANCE  DISTANCE_GROUP  CARRIER_DELAY  \
# count       445827.000000  ...  445827.000000   445827.000000   70882.000000
# unique                NaN  ...            NaN             NaN            NaN
# top                   NaN  ...            NaN             NaN            NaN
# freq                  NaN  ...            NaN             NaN            NaN
# mean            25.724613  ...     844.233880        3.848746      20.921912
# std             16.752301  ...     610.349957        2.396397      57.041917
# min              1.000000  ...      31.000000        1.000000       0.000000
# 25%             12.000000  ...     391.000000        2.000000       0.000000
# 50%             24.000000  ...     679.000000        3.000000       2.000000
# 75%             40.000000  ...    1086.000000        5.000000      20.000000
# max             78.000000  ...    4983.000000       11.000000    1659.000000
#
#         WEATHER_DELAY     NAS_DELAY  SECURITY_DELAY  LATE_AIRCRAFT_DELAY  \
# count    70882.000000  70882.000000    70882.000000         70882.000000
# unique            NaN           NaN             NaN                  NaN
# top               NaN           NaN             NaN                  NaN
# freq              NaN           NaN             NaN                  NaN
# mean         2.836573     12.680455        0.080415            21.635450
# std         23.306995     24.859425        2.070844            41.991917
# min          0.000000      0.000000        0.000000             0.000000
# 25%          0.000000      0.000000        0.000000             0.000000
# 50%          0.000000      2.000000        0.000000             0.000000
# 75%          0.000000     18.000000        0.000000            26.000000
# max       1093.000000    755.000000      242.000000          1158.000000
#
#         FIRST_DEP_TIME  TOTAL_ADD_GTIME  LONGEST_ADD_GTIME
# count      2552.000000      2552.000000        2552.000000
# unique             NaN              NaN                NaN
# top                NaN              NaN                NaN
# freq               NaN              NaN                NaN
# mean       1236.022335        32.054075          31.776254
# std         513.040425        25.993098          25.698255
# min           6.000000         1.000000           1.000000
# 25%         805.000000        15.000000          15.000000
# 50%        1149.000000        25.000000          25.000000
# 75%        1657.000000        39.000000          39.000000
# max        2354.000000       176.000000         176.000000
#
# [11 rows x 50 columns]

# %%
df.loc[:,"WHEELS_ON":"ARR_TIME_BLK"].head(10)
# Out:
#    WHEELS_ON  TAXI_IN  CRS_ARR_TIME  ARR_TIME  ARR_DELAY  ARR_DELAY_NEW  \
# 0     1424.0      8.0          1438    1432.0       -6.0            0.0
# 1     1416.0     10.0          1438    1426.0      -12.0            0.0
# 2     1431.0     14.0          1438    1445.0        7.0            7.0
# 3     1424.0      9.0          1438    1433.0       -5.0            0.0
# 4     1617.0     14.0          1438    1631.0      113.0          113.0
# 5     1426.0      9.0          1438    1435.0       -3.0            0.0
# 6     1429.0      9.0          1438    1438.0        0.0            0.0
# 7     1419.0     12.0          1438    1431.0       -7.0            0.0
# 8     1420.0      8.0          1438    1428.0      -10.0            0.0
# 9     1423.0     11.0          1438    1434.0       -4.0            0.0
#
#    ARR_DEL15  ARR_DELAY_GROUP ARR_TIME_BLK
# 0        0.0             -1.0    1400-1459
# 1        0.0             -1.0    1400-1459
# 2        0.0              0.0    1400-1459
# 3        0.0             -1.0    1400-1459
# 4        1.0              7.0    1400-1459
# 5        0.0             -1.0    1400-1459
# 6        0.0              0.0    1400-1459
# 7        0.0             -1.0    1400-1459
# 8        0.0             -1.0    1400-1459
# 9        0.0             -1.0    1400-1459

# %%
columns_to_drop = ["DEP_TIME","DEP_DELAY_NEW","DEP_DEL15","DEP_DELAY_GROUP","ARR_TIME","ARR_DELAY_NEW","ARR_DEL15","ARR_DELAY_GROUP"]
df.drop(columns_to_drop, axis=1, inplace=True)
df.shape
# Out:
# (445827, 42)

# %%
print(df.columns)
# Out:
# Index(['QUARTER', 'MONTH', 'DAY_OF_MONTH', 'DAY_OF_WEEK', 'UNIQUE_CARRIER',
#        'TAIL_NUM', 'FL_NUM', 'ORIGIN_AIRPORT_ID', 'ORIGIN_CITY_MARKET_ID',
#        'ORIGIN_STATE_FIPS', 'ORIGIN_WAC', 'DEST_AIRPORT_ID',
#        'DEST_CITY_MARKET_ID', 'DEST_STATE_FIPS', 'DEST_WAC', 'CRS_DEP_TIME',
#        'DEP_DELAY', 'DEP_TIME_BLK', 'TAXI_OUT', 'WHEELS_OFF', 'WHEELS_ON',
#        'TAXI_IN', 'CRS_ARR_TIME', 'ARR_DELAY', 'ARR_TIME_BLK', 'CANCELLED',
#        'CANCELLATION_CODE', 'DIVERTED', 'CRS_ELAPSED_TIME',
#        'ACTUAL_ELAPSED_TIME', 'AIR_TIME', 'FLIGHTS', 'DISTANCE',
#        'DISTANCE_GROUP', 'CARRIER_DELAY', 'WEATHER_DELAY', 'NAS_DELAY',
#        'SECURITY_DELAY', 'LATE_AIRCRAFT_DELAY', 'FIRST_DEP_TIME',
#        'TOTAL_ADD_GTIME', 'LONGEST_ADD_GTIME'],
#       dtype='object')

# %%
df.describe(include="all")
# Out:
#          QUARTER     MONTH   DAY_OF_MONTH    DAY_OF_WEEK UNIQUE_CARRIER  \
# count   445827.0  445827.0  445827.000000  445827.000000         445827
# unique       NaN       NaN            NaN            NaN             12
# top          NaN       NaN            NaN            NaN             WN
# freq         NaN       NaN            NaN            NaN         104154
# mean         1.0       1.0      15.893510       4.113815            NaN
# std          0.0       0.0       8.936692       2.005007            NaN
# min          1.0       1.0       1.000000       1.000000            NaN
# 25%          1.0       1.0       8.000000       2.000000            NaN
# 50%          1.0       1.0      16.000000       4.000000            NaN
# 75%          1.0       1.0      24.000000       6.000000            NaN
# max          1.0       1.0      31.000000       7.000000            NaN
#
#        TAIL_NUM         FL_NUM  ORIGIN_AIRPORT_ID  ORIGIN_CITY_MARKET_ID  \
# count    441583  445827.000000      445827.000000          445827.000000
# unique     4238            NaN                NaN                    NaN
# top      N489HA            NaN                NaN                    NaN
# freq        358            NaN                NaN                    NaN
# mean        NaN    2078.856456       12682.120789           31723.938281
# std         NaN    1757.269780        1529.485604            1280.460591
# min         NaN       1.000000       10135.000000           30070.000000
# 25%         NaN     702.000000       11292.000000           30615.000000
# 50%         NaN    1594.000000       12889.000000           31453.000000
# 75%         NaN    2763.000000       14027.000000           32467.000000
# max         NaN    7438.000000       16218.000000           35991.000000
#
#         ORIGIN_STATE_FIPS  ...       DISTANCE  DISTANCE_GROUP  CARRIER_DELAY  \
# count       445827.000000  ...  445827.000000   445827.000000   70882.000000
# unique                NaN  ...            NaN             NaN            NaN
# top                   NaN  ...            NaN             NaN            NaN
# freq                  NaN  ...            NaN             NaN            NaN
# mean            25.724613  ...     844.233880        3.848746      20.921912
# std             16.752301  ...     610.349957        2.396397      57.041917
# min              1.000000  ...      31.000000        1.000000       0.000000
# 25%             12.000000  ...     391.000000        2.000000       0.000000
# 50%             24.000000  ...     679.000000        3.000000       2.000000
# 75%             40.000000  ...    1086.000000        5.000000      20.000000
# max             78.000000  ...    4983.000000       11.000000    1659.000000
#
#         WEATHER_DELAY     NAS_DELAY  SECURITY_DELAY  LATE_AIRCRAFT_DELAY  \
# count    70882.000000  70882.000000    70882.000000         70882.000000
# unique            NaN           NaN             NaN                  NaN
# top               NaN           NaN             NaN                  NaN
# freq              NaN           NaN             NaN                  NaN
# mean         2.836573     12.680455        0.080415            21.635450
# std         23.306995     24.859425        2.070844            41.991917
# min          0.000000      0.000000        0.000000             0.000000
# 25%          0.000000      0.000000        0.000000             0.000000
# 50%          0.000000      2.000000        0.000000             0.000000
# 75%          0.000000     18.000000        0.000000            26.000000
# max       1093.000000    755.000000      242.000000          1158.000000
#
#        FIRST_DEP_TIME  TOTAL_ADD_GTIME  LONGEST_ADD_GTIME
# count     2552.000000      2552.000000        2552.000000
# unique            NaN              NaN                NaN
# top               NaN              NaN                NaN
# freq              NaN              NaN                NaN
# mean      1236.022335        32.054075          31.776254
# std        513.040425        25.993098          25.698255
# min          6.000000         1.000000           1.000000
# 25%        805.000000        15.000000          15.000000
# 50%       1149.000000        25.000000          25.000000
# 75%       1657.000000        39.000000          39.000000
# max       2354.000000       176.000000         176.000000
#
# [11 rows x 42 columns]

# %%
print(df["FLIGHTS"].plot(kind="hist"))
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
columns_to_drop = ["FLIGHTS","DISTANCE_GROUP"]
df.drop(columns_to_drop, axis=1, inplace=True)
df.shape
# Out:
# (445827, 40)

# %%
df.loc[50:75,"FIRST_DEP_TIME":]
# Out:
#     FIRST_DEP_TIME  TOTAL_ADD_GTIME  LONGEST_ADD_GTIME
# 50             NaN              NaN                NaN
# 51             NaN              NaN                NaN
# 52             NaN              NaN                NaN
# 53             NaN              NaN                NaN
# 54             NaN              NaN                NaN
# 55             NaN              NaN                NaN
# 56             NaN              NaN                NaN
# 57             NaN              NaN                NaN
# 58             NaN              NaN                NaN
# 59             NaN              NaN                NaN
# 60             NaN              NaN                NaN
# 61             NaN              NaN                NaN
# 62             NaN              NaN                NaN
# 63             NaN              NaN                NaN
# 64             NaN              NaN                NaN
# 65             NaN              NaN                NaN
# 66             NaN              NaN                NaN
# 67             NaN              NaN                NaN
# 68             NaN              NaN                NaN
# 69             NaN              NaN                NaN
# 70           642.0             11.0               11.0
# 71             NaN              NaN                NaN
# 72             NaN              NaN                NaN
# 73             NaN              NaN                NaN
# 74             NaN              NaN                NaN
# 75             NaN              NaN                NaN

# %%
print(df.columns)
df.shape
# Out:
# Index(['QUARTER', 'MONTH', 'DAY_OF_MONTH', 'DAY_OF_WEEK', 'UNIQUE_CARRIER',
#        'TAIL_NUM', 'FL_NUM', 'ORIGIN_AIRPORT_ID', 'ORIGIN_CITY_MARKET_ID',
#        'ORIGIN_STATE_FIPS', 'ORIGIN_WAC', 'DEST_AIRPORT_ID',
#        'DEST_CITY_MARKET_ID', 'DEST_STATE_FIPS', 'DEST_WAC', 'CRS_DEP_TIME',
#        'DEP_DELAY', 'DEP_TIME_BLK', 'TAXI_OUT', 'WHEELS_OFF', 'WHEELS_ON',
#        'TAXI_IN', 'CRS_ARR_TIME', 'ARR_DELAY', 'ARR_TIME_BLK', 'CANCELLED',
#        'CANCELLATION_CODE', 'DIVERTED', 'CRS_ELAPSED_TIME',
#        'ACTUAL_ELAPSED_TIME', 'AIR_TIME', 'DISTANCE', 'CARRIER_DELAY',
#        'WEATHER_DELAY', 'NAS_DELAY', 'SECURITY_DELAY', 'LATE_AIRCRAFT_DELAY',
#        'FIRST_DEP_TIME', 'TOTAL_ADD_GTIME', 'LONGEST_ADD_GTIME'],
#       dtype='object')
# (445827, 40)

# %%
df["ARR_DELAY"].describe()
# Out:
# count    433298.000000
# mean          1.533654
# std          39.096842
# min         -79.000000
# 25%         -15.000000
# 50%          -7.000000
# 75%           5.000000
# max        1659.000000
# Name: ARR_DELAY, dtype: float64

# %%
(df.isna().sum(axis=1)/len(df.columns)).plot(kind="hist",bins=50)

# %%
df[(df.isna().sum(axis=1)/len(df.columns))>0.25]
# Out:
#         QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK UNIQUE_CARRIER TAIL_NUM  \
# 72            1      1            16            6             AA   N3CXAA
# 79            1      1            23            6             AA      NaN
# 80            1      1            24            7             AA   N3DGAA
# 81            1      1            25            1             AA   N3MNAA
# 102           1      1            15            5             AA   N3JSAA
# 110           1      1            23            6             AA      NaN
# 111           1      1            24            7             AA      NaN
# 112           1      1            25            1             AA   N3KJAA
# 189           1      1             7            4             AA   N4YUAA
# 260           1      1            22            5             AA      NaN
# 261           1      1            23            6             AA      NaN
# 262           1      1            24            7             AA      NaN
# 263           1      1            25            1             AA      NaN
# 346           1      1            15            5             AA   N3ALAA
# 490           1      1             5            2             AA      NaN
# 573           1      1            22            5             AA   N385AA
# 574           1      1            23            6             AA      NaN
# 575           1      1            24            7             AA      NaN
# 605           1      1            23            6             AA      NaN
# 606           1      1            24            7             AA   N397AA
# 635           1      1            23            6             AA      NaN
# 636           1      1            24            7             AA      NaN
# 637           1      1            25            1             AA   N3GSAA
# 665           1      1            23            6             AA      NaN
# 666           1      1            24            7             AA      NaN
# 667           1      1            25            1             AA   N3JFAA
# 745           1      1            10            7             AA   N3EXAA
# 802           1      1             5            2             AA   N850AA
# 878           1      1            23            6             AA      NaN
# 879           1      1            24            7             AA      NaN
# ...         ...    ...           ...          ...            ...      ...
# 443088        1      1            26            2             WN      NaN
# 443110        1      1            26            2             WN   N212WN
IR_TIME  DISTANCE  CARRIER_DELAY  WEATHER_DELAY  NAS_DELAY  \
# 72      ...       NaN    2422.0            NaN            NaN        NaN
# 79      ...       NaN    2422.0            NaN            NaN        NaN
# 80      ...       NaN    2422.0            NaN            NaN        NaN
# 81      ...       NaN    2422.0            NaN            NaN        NaN
# 102     ...       NaN    2422.0            NaN            NaN        NaN
# 110     ...       NaN    2422.0            NaN            NaN        NaN
# 111     ...       NaN    2422.0            NaN            NaN        NaN
# 112     ...       NaN    2422.0            NaN            NaN        NaN
# 189     ...       NaN     550.0            NaN            NaN        NaN
# 260     ...       NaN    2311.0            NaN            NaN        NaN
# 261     ...       NaN    2311.0            NaN            NaN        NaN
# 262     ...       NaN    2311.0            NaN            NaN        NaN
# 263     ...       NaN    2311.0            NaN            NaN        NaN
# 346     ...       NaN    1709.0            NaN            NaN        NaN
# 490     ...       NaN    1121.0            NaN            NaN        NaN
# 573     ...       NaN    1089.0            NaN            NaN        NaN
# 574     ...       NaN    1089.0            NaN            NaN        NaN
# 575     ...       NaN    1089.0            NaN            NaN        NaN
# 605     ...       NaN    1089.0            NaN            NaN        NaN
# 606     ...       NaN    1089.0            NaN            NaN        NaN
# 635     ...       NaN    1521.0            NaN            NaN        NaN
# 636     ...       NaN    1521.0            NaN            NaN        NaN
# 637     ...       NaN    1521.0            NaN            NaN        NaN
# 665     ...       NaN    1521.0            NaN            NaN        NaN
# 666     ...       NaN    1521.0            NaN            NaN        NaN
# 667     ...       NaN    1521.0            NaN            NaN        NaN
# 745     ...       NaN    1055.0            NaN            NaN        NaN
# 802     ...       NaN     236.0            NaN            NaN        NaN
# 878     ...       NaN     944.0            NaN            NaN        NaN
# 879     ...       NaN     944.0            NaN            NaN        NaN
# ...     ...       ...       ...            ...            ...        ...
# 443088  ...       NaN     460.0            NaN            NaN        NaN
# 443110  ...       NaN    1363.0            NaN            NaN        NaN
# 443328  ...       NaN     711.0            NaN            NaN        NaN
# 443370  ...       NaN     632.0            NaN            NaN        NaN
# 443382  ...       NaN     271.0            NaN            NaN        NaN
# 443497  ...       NaN     998.0            NaN            NaN        NaN
# 443500  ...       NaN     436.0            NaN            NaN        NaN
# 443514  ...       NaN     302.0            NaN            NaN        NaN
# 443582  ...       NaN     337.0            NaN            NaN        NaN
# 443615  ...       NaN     446.0            NaN            NaN        NaN
# 444212  ...       NaN     325.0            NaN            NaN        NaN
# 444214  ...       NaN     325.0            NaN            NaN        NaN
# 444273  ...       NaN     446.0            NaN            NaN        NaN
# 444503  ...       NaN     621.0            NaN            NaN        NaN
# 444610  ...       NaN     338.0            NaN            NaN        NaN
# 444794  ...       NaN     486.0            NaN            NaN        NaN
# 445038  ...       NaN     369.0            NaN            NaN        NaN
# 445120  ...       NaN     601.0            NaN            NaN        NaN
# 445239  ...       NaN     345.0            NaN            NaN        NaN
# 445240  ...       NaN     345.0            NaN            NaN        NaN
# 445243  ...       NaN     345.0            NaN            NaN        NaN
# 445431             NaN                  NaN            NaN              NaN
# 445471             NaN                  NaN            NaN              NaN
# 445561             NaN                  NaN            NaN              NaN
#
#         LONGEST_ADD_GTIME
# 72                    NaN
# 79                    NaN
# 80                    NaN
# 81                    NaN
# 102                   NaN
# 110                   NaN
# 111                   NaN
# 112                   NaN
# 189                   NaN
# 260                   NaN
# 261                   NaN
# 262                   NaN
# 263                   NaN
# 346                   NaN
# 490                   NaN
# 573                   NaN
# 574                   NaN
# 575                   NaN
# 605                   NaN
# 606                   NaN
# 635                   NaN
# 636                   NaN
# 637                   NaN
# 665                   NaN
# 666                   NaN
# 667                   NaN
# 745                   NaN
# 802                   NaN
# 878                   NaN
# 879                   NaN
# ...                   ...
# 443088                NaN
# 443110                NaN
# 443328                NaN
# 443370                NaN
# 443382                NaN
# 443497                NaN
# 443500                NaN
# 443514                NaN
# 443582                NaN
# 443615                NaN
# 444212                NaN
# 444214                NaN
# 444273                NaN
# 444503                NaN
# 444610                NaN
# 444794                NaN
# 445038                NaN
# 445120                NaN
# 445239                NaN
# 445240                NaN
# 445243                NaN
# 445244                NaN
# 445246                NaN
# 445248                NaN
# 445250                NaN
# 445331                NaN
# 445332                NaN
# 445431                NaN
# 445471                NaN
# 445561                NaN
#
# [12519 rows x 40 columns]

# %%
df["ARR_DELAY"].plot(kind="hist",bins=100)

# %%
df.loc[50:75,"WHEELS_ON":"LATE_AIRCRAFT_DELAY"]
# Out:
#     WHEELS_ON  TAXI_IN  CRS_ARR_TIME  ARR_DELAY ARR_TIME_BLK  CANCELLED  \
# 50     1704.0      4.0          1730      -22.0    1700-1759        0.0
# 51     1715.0      5.0          1730      -10.0    1700-1759        0.0
# 52     1637.0      6.0          1730      -47.0    1700-1759        0.0
# 53     1725.0      6.0          1730        1.0    1700-1759        0.0
# 54     1702.0      6.0          1730      -22.0    1700-1759        0.0
# 55     1808.0      5.0          1730       43.0    1700-1759        0.0
# 56     1721.0     15.0          1730        6.0    1700-1759        0.0
# 57     1603.0      7.0          1602        8.0    1600-1659        0.0
# 58     1556.0     17.0          1602       11.0    1600-1659        0.0
# 59     1539.0      8.0          1602      -15.0    1600-1659        0.0
# 60     1546.0      5.0          1602      -11.0    1600-1659        0.0
# 61     1519.0      5.0          1527       -3.0    1500-1559        0.0
# 62     1514.0      4.0          1527       -9.0    1500-1559        0.0
# 63     1517.0      5.0          1527       -5.0    1500-1559        0.0
# 64     1518.0      9.0          1527        0.0    1500-1559        0.0
# 65     1521.0     15.0          1527        9.0    1500-1559        0.0
# 66     1601.0     10.0          1527       44.0    1500-1559        0.0
# 67     1514.0      5.0          1527       -8.0    1500-1559        0.0
# 68     1445.0      7.0          1506      -14.0    1500-1559        0.0
# 69     1436.0      5.0          1506      -25.0    1500-1559        0.0
# 70     1530.0      7.0          1506       31.0    1500-1559        0.0
# 71     1444.0      7.0          1506      -15.0    1500-1559        0.0
# 72        NaN      NaN          1501        NaN    1500-1559        1.0
# 73     1525.0      7.0          1506       26.0    1500-1559        0.0
# 74     1433.0      6.0          1506      -27.0    1500-1559        0.0
# 75     1441.0      6.0          1506      -19.0    1500-1559        0.0
#
#    CANCELLATION_CODE  DIVERTED  CRS_ELAPSED_TIME  ACTUAL_ELAPSED_TIME  \
# 50               NaN       0.0             187.0                170.0
# 51               NaN       0.0             187.0                181.0
# 52               NaN       0.0             187.0                145.0
# 53               NaN       0.0             187.0                176.0
# 54               NaN       0.0             187.0                167.0
# 55               NaN       0.0             187.0                164.0
# 56               NaN       0.0             187.0                193.0
# 57               NaN       0.0             317.0                329.0
# 58               NaN       0.0             317.0                336.0
# 59               NaN       0.0             317.0                304.0
# 60               NaN       0.0             317.0                314.0
# 61               NaN       0.0             317.0                316.0
# 62               NaN       0.0             317.0                315.0
# 63               NaN       0.0             317.0                318.0
# 64               NaN       0.0             317.0                326.0
# 65               NaN       0.0             317.0                333.0
# 66               NaN       0.0             317.0                360.0
# 67               NaN       0.0             317.0                310.0
# 68               NaN       0.0             321.0                316.0
# 69               NaN       0.0             321.0                302.0
# 70               NaN       0.0             321.0                300.0
# 71               NaN       0.0             321.0                312.0
# 72                 A       0.0             321.0                  NaN
# 73               NaN       0.0             321.0                304.0
# 74               NaN       0.0             321.0                298.0
# 75               NaN       0.0             321.0                309.0
#
#     AIR_TIME  DISTANCE  CARRIER_DELAY  WEATHER_DELAY  NAS_DELAY  \
# 50     155.0     986.0            NaN            NaN        NaN
# 51     165.0     986.0            NaN            NaN        NaN
# 52     128.0     986.0            NaN            NaN        NaN
# 53     137.0     986.0            NaN            NaN        NaN
# 54     142.0     986.0            NaN            NaN        NaN
# 55     146.0     986.0            5.0            0.0        0.0
# 56     156.0     986.0            NaN            NaN        NaN
# 57     294.0    2422.0            NaN            NaN        NaN
# 58     292.0    2422.0            NaN            NaN        NaN
# 59     277.0    2422.0            NaN            NaN        NaN
# 60     294.0    2422.0            NaN            NaN        NaN
# 61     296.0    2422.0            NaN            NaN        NaN
# 62     294.0    2422.0            NaN            NaN        NaN
# 63     297.0    2422.0            NaN            NaN        NaN
# 64     295.0    2422.0            NaN            NaN        NaN
# 65     288.0    2422.0            NaN            NaN        NaN
# 66     335.0    2422.0            1.0            0.0       43.0
# 67     287.0    2422.0            NaN            NaN        NaN
# 68     288.0    2422.0            NaN            NaN        NaN
# 69     283.0    2422.0            NaN            NaN        NaN
# 70     274.0    2422.0           31.0            0.0        0.0
# 71     285.0    2422.0            NaN            NaN        NaN
# 72       NaN    2422.0            NaN            NaN        NaN
# 73     281.0    2422.0           26.0            0.0        0.0
# 74     273.0    2422.0            NaN            NaN        NaN
# 75     287.0    2422.0            NaN            NaN        NaN
#
#     SECURITY_DELAY  LATE_AIRCRAFT_DELAY
# 50             NaN                  NaN
# 51             NaN                  NaN
# 52             NaN                  NaN
# 53             NaN                  NaN
# 54             NaN                  NaN
# 55             0.0                 38.0
# 56             NaN                  NaN
# 57             NaN                  NaN
# 58             NaN                  NaN
# 59             NaN                  NaN
# 60             NaN                  NaN
# 61             NaN                  NaN
# 62             NaN                  NaN
# 63             NaN                  NaN
# 64             NaN                  NaN
# 65             NaN                  NaN
# 66             0.0                  0.0
# 67             NaN                  NaN
# 68             NaN                  NaN
# 69             NaN                  NaN
# 70             0.0                  0.0
# 71             NaN                  NaN
# 72             NaN                  NaN
# 73             0.0                  0.0
# 74             NaN                  NaN
# 75             NaN                  NaN
